# %%
import names
from mtv.utils import read_config
cf = read_config('./mtv/config.yaml')

from mongoengine import connect
from pymongo.database import Database
from gridfs import GridFS

database = 'mtv-results2-stock'

_db = connect(db=database, host=cf['host'], port=cf['port'],
               username=cf['username'], password=cf['password'])
_fs = GridFS(Database(_db, database))


from mtv.db import schema
    
for user_doc in user_docs:
    user_doc.picture = "https://user-images.githubusercontent.com/8490637/93004647-d895c100-f516-11ea-8c74-332d98bbf2ad.png"
    user_doc.save()
    
user_docs = schema.User.find()
for user_doc in user_docs:
    o_name = user_doc.name
    name = names.get_first_name()
    if schema.User.find_one(name=name) is not None:
        name = names.get_first_name()
    user_doc.name = name
    print(name)
    user_doc.save()
    
    docs = schema.Annotation.find(created_by=o_name)
    for doc in docs:
        doc.created_by = name
        doc.save()
    
    docs = schema.Dataset.find(created_by=o_name)
    for doc in docs:
        doc.created_by = name
        doc.save()
    
    docs = schema.EventInteraction.find(created_by=o_name)
    for doc in docs:
        doc.created_by = name
        doc.save()
    
    docs = schema.Experiment.find(created_by=o_name)
    for doc in docs:
        doc.created_by = name
        doc.save()
    
    docs = schema.Pipeline.find(created_by=o_name)
    for doc in docs:
        doc.created_by = name
        doc.save()
    
    docs = schema.Signal.find(created_by=o_name)
    for doc in docs:
        doc.created_by = name
        doc.save()
    
    docs = schema.Template.find(created_by=o_name)
    for doc in docs:
        doc.created_by = name
        doc.save()
